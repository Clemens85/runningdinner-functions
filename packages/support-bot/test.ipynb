# %%
# %load_ext autoreload
# %autoreload 2

# %%
from dotenv import load_dotenv
import os
load_dotenv(override=True)
os.environ['OPENAI_API_KEY'] = os.getenv('OPENAI_API_KEY', '')

# %%
from SupportBot import SupportBot

# %%
support_bot = SupportBot( {"configurable": {"thread_id": "a"}} )

# %%
support_bot.visualize_graph()

# %%
from UserRequest import UserRequest

# %%
    question = "Unterstützt das Tool auch kürzeste Wegen bei den Routen? Wir veranstalten ein Event in Berlin und da ist es wichtig, dass man nicht vom einem Rand zum anderen Rand muss. Lg Jan"
    user_request = UserRequest(question=question, thread_id='a')
    response = support_bot.query(user_request)
    print (response)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 3
#       1 question = "Unterstützt das Tool auch kürzeste Wegen bei den Routen? Wir veranstalten ein Event in Berlin und da ist es wichtig, dass man nicht vom einem Rand zum anderen Rand muss. Lg Jan"
#       2 user_request = UserRequest(question=question, thread_id='a')
# ----> 3 response = support_bot.query(user_request)
#       4 print (response)
#
# File C:\Projects\runningdinner-functions\packages\support-bot\SupportBot.py:172, in query(self, user_request)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# IndexError: list index out of range
